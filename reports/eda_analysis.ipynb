# %%
import pandas as pd

df = pd.read_csv("../data/processed/dashboard_summary_final.csv")

df.head()

# %%
df.describe()

# %%
df.corr(numeric_only=True)

# %% [markdown]
# EDA Findings
#
# 1. HDFC Top 100 Fund has highest return.
# 2. SBI Bluechip has lowest return.
# 3. ICICI Prudential has stable volatility.
# 4. Sharpe Ratio highest for HDFC.
# 5. Returns vary significantly across funds.
