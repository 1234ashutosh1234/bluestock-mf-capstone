# %%
import pandas as pd

df = pd.read_csv("../data/processed/dashboard_summary_final.csv")

df
# Out:
#    amfi_code  start_nav   end_nav   return_pct  volatility  sharpe_ratio  \
# 0     118632    12.2191  106.1272   768.535326    0.166915      0.948544
# 1     119551   102.2299  161.3775    57.857437    0.087114      0.062948
# 2     120503    13.6318  113.6849   733.968368    0.009644      0.065438
# 3     120841    30.5643  281.1083   819.727591    0.154202      1.108882
# 4     125497    12.7775  214.6767  1580.115046    0.152034      1.523487
#
#                       scheme_name
# 0     Nippon India Large Cap Fund
# 1               SBI Bluechip Fund
# 2  ICICI Prudential Bluechip Fund
# 3             Kotak Bluechip Fund
# 4               HDFC Top 100 Fund

# %%
df.sort_values(
    "return_pct",
    ascending=False
)
# Out:
#    amfi_code  start_nav   end_nav   return_pct  volatility  sharpe_ratio  \
# 4     125497    12.7775  214.6767  1580.115046    0.152034      1.523487
# 3     120841    30.5643  281.1083   819.727591    0.154202      1.108882
# 0     118632    12.2191  106.1272   768.535326    0.166915      0.948544
# 2     120503    13.6318  113.6849   733.968368    0.009644      0.065438
# 1     119551   102.2299  161.3775    57.857437    0.087114      0.062948
#
#                       scheme_name
# 4               HDFC Top 100 Fund
# 3             Kotak Bluechip Fund
# 0     Nippon India Large Cap Fund
# 2  ICICI Prudential Bluechip Fund
# 1               SBI Bluechip Fund

# %%
df.sort_values(
    "sharpe_ratio",
    ascending=False
)
# Out:
#    amfi_code  start_nav   end_nav   return_pct  volatility  sharpe_ratio  \
# 4     125497    12.7775  214.6767  1580.115046    0.152034      1.523487
# 3     120841    30.5643  281.1083   819.727591    0.154202      1.108882
# 0     118632    12.2191  106.1272   768.535326    0.166915      0.948544
# 2     120503    13.6318  113.6849   733.968368    0.009644      0.065438
# 1     119551   102.2299  161.3775    57.857437    0.087114      0.062948
#
#                       scheme_name
# 4               HDFC Top 100 Fund
# 3             Kotak Bluechip Fund
# 0     Nippon India Large Cap Fund
# 2  ICICI Prudential Bluechip Fund
# 1               SBI Bluechip Fund

# %% [markdown]
# Performance Analytics Findings
#
# 1. HDFC Top 100 Fund ranks first.
# 2. Kotak Bluechip ranks second.
# 3. Sharpe ratio confirms HDFC leadership.
# 4. ICICI offers moderate return.
# 5. SBI has weakest performance.
